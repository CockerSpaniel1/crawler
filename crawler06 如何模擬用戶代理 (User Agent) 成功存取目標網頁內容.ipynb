# %%
import requests
head = {"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36"}
res = requests.get("https://buy.yungching.com.tw/region", headers=head)
print(res.text)
# Out:
# <!DOCTYPE HTML>
# <!--[if lte IE 8]>    <html class="no-js lt-ie9" lang="zh-Hant-TW" > <![endif]-->
# <!--[if gt IE 8]><!-->
# <html dir="ltr" lang="zh-Hant-TW" itemscope itemtype="http://schema.org" >
# <!--<![endif]-->
# <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">
#     <meta charset="UTF-8">
#     <title> 台北市房屋。買屋、購屋、買房子、找房屋、實價登錄 | 永慶房仲網超過14萬筆分店刊登物件</title>
#
#     <meta name="description" content="最新台北市房屋 。最新更新時間：2024/5/5。台北市 房屋，全部5278件，新青安推薦物件1100件，新進物件641件，最新降價1682件。房仲網第一品牌，永慶房仲網超過14萬筆分店刊登物件。買屋、購屋、買房子、找房屋、實價登錄首選永慶房仲網，還有買屋注意事項、實價登錄、房貸試算、實境找房，讓買屋更省時省力。" />
#     <meta property="fb:app_id" content="320559141361882" />
#     <meta property="og:locale" content="zh_TW" />
#     <meta property="og:title" itemprop="name" content=" 台北市房屋。買屋、購屋、買房子、找房屋、實價登錄 | 永慶房仲網超過14萬筆分店刊登物件" />
#     <meta property="og:description" content="最新台北市房屋 。最新更新時間：2024/5/5。台北市 房屋，全部5278件，新青安推薦物件1100件，新進物件641件，最新降價1682件。房仲網第一品牌，永慶房仲網超過14萬筆分店刊登物件。買屋、購屋、買房子、找房屋、實價登錄首選永慶房仲網，還有買屋注意事項、實價登錄、房貸試算、實境找房，讓買屋更省時省力。" />
#     <meta property="og:url" itemprop="url" content="https://buy.yungching.com.tw/region/台北市_c" />
#     <meta property="og:image" itemprop="image" content="https://buy.yungching.com.tw/Content/img/FB-400x300.png" />
#     <meta property="og:site_name" content="永慶房仲網" />
#     <link rel="canonical" href="https://buy.yungching.com.tw/region/台北市_c" />
#     <link href="//cdn.yungching.com.tw/min/b=fp&f=common/font-awesome/css/font-awesome.min.css,hf/libs/cirobox/css/cirobox.css&v=C2015073001" rel="stylesheet">
#     <link rel="apple-touch-icon" href="/Content/img/apple-icon-60x60.png" sizes="57x57" />
#     <link rel="apple-touch-icon" href="/Content/img/apple-icon-76x76.png" sizes="72x72" />
#     <link rel="apple-touch-icon" href="/Content/img/apple-icon-120x120.png" sizes="114x114" />
#     <link rel="apple-touch-icon" href="/Content/img/apple-icon-152x152.png" sizes="144x144" />
#
#
#     <link rel="stylesheet" href="//cdn.yungching.com.tw/min/b=fp/yc/buy&f=Content/css/index.css&v=202404290002">
#     <link rel="stylesheet" href="/Angular/Styles/styles.css?v=202404290002">
#     <link rel="stylesheet" href="/Angular/Svgs/icon.css?v=202404290002">
#     <style>
#         *,
#         :after,
#         :before {
#             box-sizing: content-box;
#         }
#     </style>
#
#     <script type="text/javascript" src="/Scripts/libs/modernizr_custom.js" defer></script>
#     <script type="text/javascript" src="//admd.yungching.com.tw/AD.aspx"></script>
#
#
#         <script type="text/javascript">
#             var ltm_data = {
#                 url: "https://buy.yungching.com.tw/region/台北市_c",
#                 pagetype: "house_area_search_result",
#                 pageversion: "web",
#                 member_token: "",
#                 trid: "add80578-05e3-4a6f-9123-8232cee98c26",
#                 ltm: {
#                     source: "",
#                     campaign: "",
#                     medium: "",
#                     term: "",
#                     content: "",
#                 },
#                 pagedata: {
#                     areas: [{city:"台北市",district:""}],
#                     total_price_start: "",
#                     total_price_end: "",
#                     price_start: "",
#                     price_end: "",
#                     pin_start: "",
#                     pin_end: "",
#                     room_start: "",
#                     room_end: "",
#                     age_start: "",
#                     age_end: "",
#                     floor_start: "",
#                     floor_end: "",
#                     floor_top: "",
#                     purpose: [],
#                     type: [],
#                     direction: [],
#                     label: [],
#                     parking_space: "",
#                     barrier_free: "",
#                     keyword: "",
#                     brand:[1]
#                 },
#                 list_ids:["6285237","6310802","5246176","6314788","6173830","6276733","5116631","6088708","5539796","6054813","4713251","5949318","6104546","4751186","5906120","5929306","4050152","2742767","6236591","6210120","6023505","6167116","3999808","5913297","5984579","5302555","5881510","5814391","6078056","5204248"]
#             }
#
#             function gtmOnInit(){
#                 if(typeof window['gtmViewItemList']=='function' && !window.location.href.match('/map/') && ltm_data.pageversion=='web'){
#                    window['gtmViewItemList'](
#                     '$channel_$searchType_result',
#                     ltm_data.list_ids.filter(x=>x).map(x=>{
#                         return {
#                             item_id:x.toString(),
#                             item_name:x.toString(),
#                             item_list_id:'$channel_$searchType_result_$tag',
#                             item_list_name:'$channel_$searchType_result_$tag',
#                         }
#                    }))
#                 }
#             }
#         </script>
#
#
#
#     <script nomodule>window.location.replace('//www.yungching.com.tw/nosupport.html');</script>
# </head>
#
# <body ng-app="ycapp">
#     <!-- Google Tag Manager -->
#     <noscript>
#         <iframe src="//www.googletagmanager.com/ns.html?id=GTM-PKJHNQ"
#                 height="0" width="0" style="display:none;visibility:hidden"></iframe>
#     </noscript>
#     <script>var VID = '';</script>
#     <script>
#         (function (w, d, s, l, i) {
#         w[l] = w[l] || []; w[l].push({
#         'gtm.start':
#         new Date().getTime(), event: 'gtm.js'
#         }); var f = d.getElementsByTagName(s)[0],
#         j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#         '//www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#         })(window, document, 'script', 'dataLayer', 'GTM-PKJHNQ');
#     </script>
#     <!-- End Google Tag Manager -->
#
# <link rel="preload" as="script" href="//cdn.yungching.com.tw/min/b=fp/yc_common&f=footer.js&v=202404290002">
# <link rel="preload" as="script" href="//cdn.yungching.com.tw/fp/yc/common/elements/yc-ng-common.js?v=202404290002">
# <link rel="stylesheet" type="text/css" href="//cdn.yungching.com.tw/min/b=fp/yc_common&f=header.css&v=202404290002">
# <header class="l-header">
#     <yc-ng-header></yc-ng-header>
# 	<input type="hidden" id="hiddentopclid" name="hiddentopclid" value="" />
#     <input type="hidden" id="hiddentoptoken" name="hiddentoptoken" value="" />
#     <input type="hidden" id="hiddentopline" name="hiddentopline" value="n" />
# </header>
#
#
#
#
#
# <script type="application/ld+json">
#     {"@context":"https://schema.org","@type":"WebPage","sameAs":["https://www.facebook.com/yungching.tw/","https://www.youtube.com/channel/UC1_n1GCiR6V40StPXmPKUeg","https://line.me/R/ti/p/@cwa6366a"],"url":"http://buy.yungching.com.tw/region","breadcrumb":"永慶房仲網>買屋>台北市"}
# </script>
# <script type="application/ld+json">
#     {"@context":"https://schema.org","@type":"BreadcrumbList","itemListElement":{"@type":"ListItem","name":"買屋","url":"https://buy.yungching.com.tw/region/","item":{"@type":"Thing","@id":"https://buy.yungching.com.tw/region/"},"position":1}}
# </script>
# <script type="application/ld+json">
#     {"@context":"https://schema.org","@graph":[{"@type":"Product","name":"天母靜好2房車位","image":"//yccdn.yungching.com.tw/v1/image/?key=NF58Ko5oaCsMM5ZuNBXrautiyPELIvNgAoALCtT4VfbLqkYL4543txxi6AiVkGBUqVhtUUJ4lA_cF1mBh5MY1RWd5eEaa7mn9qxu8f6s-rtKfVoBsurTgAnsNQ3b1ueVa0jD0JJgeWt02Xc92Hgeax9ptXAdU5ZuHyqQdxAoaDgB84hAAJBJ-aPJnP6QjjHNJdO-8s9VPXXQ_ruSEFqcK8ShYsvown2RKluDB4vs3XCba78wTuCNPINc3dOPPQMQruh-Gt23mTzaYgmqa__ngegw_kxkxkdM5Y2LgriectG9txh5JQn0mw&width=480&height=0","brand":{"@type":"Brand","name":"Yungching"},"manufacturer":{"@type":"Organization","name":"YC0"},"offers":{"@type":"Offer","url":"https://buy.yungching.com.tw/house/6285237","price":3342.0000,"priceCurrency":"TWD"},"productID":"YC1208367"},{"@type":"Product","name":"高樓美景甲大直","image":"//yccdn.yungching.com.tw/v1/image/?key=NF58Ko5oaCtoKidNSDUU-uZT1ODIbeEsDzgAkQXKRQb3wE--Tizfimx5WE3kiOtdqVhtUUJ4lA_cF1mBh5MY1RWd5eEaa7mn9qxu8f6s-rtKfVoBsurTgAnsNQ3b1ueVa0jD0JJgeWt02Xc92Hgeax9ptXAdU5ZuHyqQdxAoaDgB84hAAJBJ-aPJnP6QjjHNJdO-8s9VPXXQ_ruSEFqcK8ShYsvown2RbJENeZqhwTM&width=480&height=0","brand":{"@type":"Brand","name":"Yungching"},"manufacturer":{"@type":"Organization","name":"YC0"},"offers":{"@type":"Offer","url":"https://buy.yungching.com.tw/house/6310802","price":4780.0000,"priceCurrency":"TWD"},"productID":"YC1198466"},{"@type":"Product","name":"極美山景三房車","image":"//yccdn.yungching.com.tw/v1/image/?key=NF58Ko5oaCvyfJsir1QuHtFsNOmLTtYLVDzUvymPTsoGzhSyeoIWeTDC_Ra-EynWqVhtUUJ4lA_cF1mBh5MY1RWd5eEaa7mn9qxu8f6s-rtKfVoBsurTgAnsNQ3b1ueVa0jD0JJgeWt02Xc92Hgeax9ptXAdU5ZuHyqQdxAoaDgB84hAAJBJ-aPJnP6QjjHNJdO-8s9VPXXQ_ruSEFqcK8ShYsvown2RbJENeZqhwTM&width=480&height=0","brand":{"@type":"Brand","name":"Yungching"},"manufacturer":{"@type":"Organization","name":"YC0"},"offers":{"@type":"Offer","url":"https://buy.yungching.com.tw/house/5246176","price":3580.0000,"priceCurrency":"TWD"},"productID":"YC1097165"},{"@type":"Product","name":"大安名人華廈3房","image":"//yccdn.yungching.com.tw/v1/image/?key=NF58Ko5oaCt8eRnyPDAcwIlYC07OTQwwvSfoUqa5UqQKB6ujBQA05wT95R5EdU4zqVhtUUJ4lA_cF1mBh5MY1RWd5eEaa7mn9qxu8f6s-rtKfVoBsurTgAnsNQ3b1ueVa0jD0JJgeWt02Xc92Hgeax9ptXAdU5ZuHyqQdxAoaDgB84hAAJBJ-aPJnP6QjjHNJdO-8s9VPXXQ_ruSEFqcK8ShYsvown2RbJENeZqhwTM&width=480&height=0","brand":{"@type":"Brand","name":"Yungching"},"manufacturer":{"@type":"Organization","name":"YC0"},"offers":{"@type":"Offer","url":"https://buy.yungching.com.tw/house/6314788","price":4950.0000,"priceCurrency":"TWD"},"productID":"YC1197312"},{"@type":"Product","name":"昇陽美妝邊間8樓","image":"//yccdn.yungching.com.tw/v1/image/?key=NF58Ko5oaCv3auKPbQm9Y3rSGXr4c0L3IRTcV5DqqpNOodRkRIEpC4ZI8mIYNtSfqVhtUUJ4lA_cF1mBh5MY1RWd5eEaa7mn9qxu8f6s-rtKfVoBsurTgAnsNQ3b1ueVa0jD0JJgeWt02Xc92Hgeax9ptXAdU5ZuHyqQdxAoaDgB84hAAJBJ-aPJnP6QjjHNJdO-8s9VPXXQ_ruSEFqcK8ShYsvown2RKluDB4vs3XCba78wTuCNPINc3dOPPQMQsZu2OGHf6on1IwmTkNi-8egw_kxkxkdM5Y2LgriectG9txh5JQn0mw&width=480&height=0","brand":{"@type":"Brand","name":"Yungching"},"manufacturer":{"@type":"Organization","name":"YC0"},"offers":{"@type":"Offer","url":"https://buy.yungching.com.tw/house/6173830","price":3268.0000,"priceCurrency":"TWD"},"productID":"YC1198383"},{"@type":"Product","name":"世界山莊四房車位","image":"//yccdn.yungching.com.tw/v1/image/?key=NF58Ko5oaCts5xi0mnkbVetfCZAXYGZec4uhEyNxd2GYadQDdN3JOOwuTEM3iyv7qVhtUUJ4lA_cF1mBh5MY1RWd5eEaa7mn9qxu8f6s-rtKfVoBsurTgAnsNQ3b1ueVa0jD0JJgeWt02Xc92Hgeax9ptXAdU5ZuHyqQdxAoaDgB84hAAJBJ-aPJnP6QjjHNJdO-8s9VPXXQ_ruSEFqcK8ShYsvown2RKluDB4vs3XCba78wTuCNPINc3dOPPQMQ7B1phpHz8Gf1IwmTkNi-8egw_kxkxkdM5Y2LgriectG9txh5JQn0mw&width=480&height=0","brand":{"@type":"Brand","name":"Yungching"},"manufacturer":{"@type":"Organization","name":"YC0"},"offers":{"@type":"Offer","url":"https://buy.yungching.com.tw/house/6276733","price":5480.0000,"priceCurrency":"TWD"},"productID":"YC1203889"},{"@type":"Product","name":"石牌捷運公園一樓","image":"//yccdn.yungching.com.tw/v1/image/?key=NF58Ko5oaCuhHKHpHcnTUKy7u8yMRwn2kMGZg0ziqEYS4KlcU7twr7fLQD7nC51vqVhtUUJ4lA_cF1mBh5MY1RWd5eEaa7mn9qxu8f6s-rtKfVoBsurTgAnsNQ3b1ueVa0jD0JJgeWt02Xc92Hgeax9pt ...
# </script>
# <script type="application/ld+json">
#     {"@context":"https://schema.org","@type":"ItemList","itemListElement":[{"@type":"ListItem","url":"https://buy.yungching.com.tw/house/6285237","position":1},{"@type":"ListItem","url":"https://buy.yungching.com.tw/house/6310802","position":2},{"@type":"ListItem","url":"https://buy.yungching.com.tw/house/5246176","position":3},{"@type":"ListItem","url":"https://buy.yungching.com.tw/house/6314788","position":4},{"@type":"ListItem","url":"https://buy.yungching.com.tw/house/6173830","position":5},{"@type":"ListItem","url":"https://buy.yungching.com.tw/house/6276733","position":6},{"@type":"ListItem","url":"https://buy.yungching.com.tw/house/5116631","position":7},{"@type":"ListItem","url":"https://buy.yungching.com.tw/house/6088708","position":8},{"@type":"ListItem","url":"https://buy.yungching.com.tw/house/5539796","position":9},{"@type":"ListItem","url":"https://buy.yungching.com.tw/house/6054813","position":10},{"@type":"ListItem","url":"https://buy.yungching.com.tw/house/4713251","position":11},{"@type":"ListItem","url":"https://buy.yungching.com.tw/house/5949318","position":12},{"@type":"ListItem","url":"https://buy.yungching.com.tw/house/6104546","position":13},{"@type":"ListItem","url":"https://buy.yungching.com.tw/house/4751186","position":14},{"@type":"ListItem","url":"https://buy.yungching.com.tw/house/5906120","position":15},{"@type":"ListItem","url":"https://buy.yungching.com.tw/house/5929306","position":16},{"@type":"ListItem","url":"https://buy.yungching.com.tw/house/4050152","position":17},{"@type":"ListItem","url":"https://buy.yungching.com.tw/house/2742767","position":18},{"@type":"ListItem","url":"https://buy.yungching.com.tw/house/6236591","position":19},{"@type":"ListItem","url":"https://buy.yungching.com.tw/house/6210120","position":20},{"@type":"ListItem","url":"https://buy.yungching.com.tw/house/6023505","position":21},{"@type":"ListItem","url":"https://buy.yungching.com.tw/house/6167116","position":22},{"@type":"ListItem","url":"https://buy.yungching.com.tw/house/3999808","position":23},{"@type":"ListItem","url":"https://buy.yungching.com.tw/house/5913297","position":24},{"@type":"ListItem","url":"https://buy.yungching.com.tw/house/5984579","position":25},{"@type":"ListItem","url":"https://buy.yungching.com.tw/house/5302555","position":26},{"@type":"ListItem","url":"https://buy.yungching.com.tw/house/5881510","position":27},{"@type":"ListItem","url":"https://buy.yungching.com.tw/house/5814391","position":28},{"@type":"ListItem","url":"https://buy.yungching.com.tw/house/6078056","position":29},{"@type":"ListItem","url":"https://buy.yungching.com.tw/house/5204248","position":30}]}
# </script>
#
#
#
#
# <div id="et-ng-belt-preload" style="height:36px;position:relative;z-index:11;margin-top:-45px;margin-bottom:45px"></div>
# <main class="l-body" ng-controller="searchCtrl" ng-cloak>
#
#     <!-- 搜尋區塊 -->
# <!-- 搜尋區塊 -->
# <div class="ng-search-bar">
#   <ul class="m-search-for-lists">
#     <li ga-buy-search ga_action="buy_search_{{ i.name }}_click" ga_label="buy_search_{{ i.name }}" ga_cat="buy_search"
#       ng-repeat="i in ::searchFor" ng-class="{'is-active': i.key == searchCondition.searchFor}"
#       ng-click="changeSearchCondition(i.key, true);" >{{ i.name }}</li>
#   </ul>
#
# <div class="m-search-field">
#   <div class="m-search-select-wrap">
#     <a href="#" class="search-select-curr ga_click_trace" ga_cat="buy_search" ga_event="buy_search_全部用途_model_click" ga_label="buy_search_全部用途_model_click">
#       <i ng-class="mainSelectOption.icon"></i> {{ mainSelectOption.name }} <i class="angle fa fa-angle-down"></i>
#     </a>
#     <ul class="search-select-option">
#       <li>
#         <a ng-click="mainSelect(0)" href class="ga_click_trace" ga_cat="buy_search" ga_event="buy_search_全部用途_model_click" ga_label="buy_search_全部用途_model_area"
#            ng-class="{ 'active' : searchCondition.mainType === 'region' }">
#            <i class="pre fa"
#               ng-class="(searchCondition.mainType === 'region') ? 'fa-check-circle' : 'fa-circle-o'" ></i></i>
#            <i class="fa fa-bars"></i> 區域找</a></li>
#       <li>
#         <a ng-click="mainSelect(1)" href class="ga_click_trace" ga_cat="buy_search" ga_event="buy_search_全部用途_model_click" ga_label="buy_search_全部用途_model_map"
#            ng-class="{ 'active' : searchCondition.mainType === 'mrt' }">
#            <i class="pre fa"
#               ng-class="(searchCondition.mainType === 'mrt') ? 'fa-check-circle' : 'fa-circle-o'" ></i>
#            <i class="i-mrt"></i> 捷運找</a></li>
#     </ul>
#   </div>
#
#   <!-- 捷運 -->
#   <div ng-show="mainSelectOption.key == 'mrt'" class="m-search-select-wrap">
#     <a href="#" class="search-select search-select-mrt">
#       <span ng-show="searchCondition.addr[0][0] != '台中市' && searchCondition.addr[0][0] != '高雄市'">台北</span>
#       <span ng-show="searchCondition.addr[0][0] == '台中市'">台中</span>
#       <span ng-show="searchCondition.addr[0][0] == '高雄市'">高雄</span>捷運
#     </a>
#     <div class="search-select-option-mrt select-option">
#       <div class="label" ng-class="{'active': searchCondition.addr[0][0] !== '台中市' && searchCondition.addr[0][0] !== '高雄市'}">
#         <a href ng-click="changeMrtMap('台北市')">台北捷運 </a></div>
#       <!-- <div class="label tc" ng-class="{'active': searchCondition.addr[0][0] === '台中市'}">
#         <a href ng-click="changeMrtMap('台中市');">台中捷運 </a></div> -->
#       <div class="label kh" ng-class="{'active': searchCondition.addr[0][0] === '高雄市'}">
#         <a href ng-click="changeMrtMap('高雄市');">高雄捷運 </a></div>
#     </div>
#   </div>
#   <!-- 捷運 -->
#
#   <!-- 縣市/鄉鎮市區 -->
#   <div ng-hide="mainSelectOption.key == 'mrt'" class="m-search-select-wrap">
#     <a href class="search-select search-select-city"
#        ga-buy-search ga_action="buy_search_%%_location_click" ga_label="buy_search_%%_location" ga_cat="buy_search">
#       {{ limitStr(searchCondition.addr) }}
#     </a>
#
#     <div class="search-select-option-cities select-option">
#       <a href class="close">&times;</a>
#       <ul>
#         <!-- 縣市 -->
#         <li ng-show="isCitySelection" ng-repeat="c in cities">
#           <a ng-click="toggleAreaSelect($index);" href ga-buy-search
#              ga_action="buy_search_%%_location_click" ga_label="buy_search_%%_location_{{ c }}" ga_cat="buy_search">{{ c }}</a>
#         </li>
#
#         <!-- 鄉鎮區域 -->
#         <li class="reset" ng-hide="isCitySelection">
#           <a href ng-click="isCitySelection = true;"
#             ga-buy-search
#             ga_action="buy_search_%%_location_click"
#             ga_label="buy_search_%%_location_reset"
#             ga_cat="buy_search"><i class="fa fa-reply" aria-hidden="true"></i> 重選縣市</a>
#         </li>
#
#         <li ng-hide="isCitySelection" ng-repeat="a in areaList">
#           <label>
#             <input area="{{ a }}" index="{{$index}}" type="checkbox" class="chkbox area-chkbox" ng-checked="selectedAreas.indexOf(a) > -1"
#                    ga-buy-search ga_action="buy_search_%%_location_click" ga_label="buy_search_%%_location_{{ searchCondition.addr[0] }}{{ a }}" ga_cat="buy_search" >
#             <span>{{ a }}</span>
#           </label>
#         </li>
#       </ul>
#     </div>
#   </div>
#
#   <div class="m-search-select-wrap">
#     <a href class="search-select search-select-price" ga-buy-search ga_action="buy_search_%%_price_click" ga_label="buy_search_%%_price" ga_cat="buy_search">{{ showRange('price') }}</a>
#     <div class="search-select-option-price select-option">
#       <label><input type="checkbox" index="-1" listtype="priceList" class="chkbox chkbox-any" chkbox-area
#         ga-buy-search ga_action="buy_search_%%_price_click" ga_label="buy_search_%%_price_none" ga_cat="buy_search"><span>總價不限</span></label>
#       <label ng-repeat="i in currPriceList">
#         <input type="checkbox" index="{{$index}}" listtype="priceList" class="chkbox" chkbox-area
#           ga-buy-search ga_action="buy_search_%%_price_click" ga_label="buy_search_%%_price_{{ currPriceList[$index - 1] || '' }}-{{ currPriceList[$index] || ''}}" ga_cat="buy_search" >
#         <span ng-if=" $index == 0 ">{{ currPriceList[$index] }} 萬以下</span>
#         <span ng-if=" $index > 0 && $index < (currPriceList.length-1) ">{{ currPriceList[$index - 1] }} 萬 - {{ currPriceList[$index] }} 萬</span>
#         <span ng-if=" $index == (currPriceList.length - 1) ">{{ currPriceList[$index - 1] }} 萬以上</span>
#       </label>
#
#       <div class="custom-block">
#         <div class="input-wrap">
#           <input index="0" listtype="priceList" class="custom-num num" type="text" size="5"> -
#           <input index="1" listtype="priceList" class="custom-num num" type="text" size="5"> 萬
#         </div>
#       </div>
#     </div>
#   </div>
#
#   <div class="m-search-select-wrap">
#     <a href class="search-select search-select-area" ga-buy-search ga_action="buy_search_%%_sqft_click" ga_label="buy_search_%%_sqft" ga_cat="buy_search">{{ showRange('pyeong') }}</a>
#     <div class="search-select-option-area select-option">
#       <div style="height: 40px; line-height: 40px; padding-left: 0.7em; margin-bottom: 0.2em; border-bottom: 1px solid #eee;">
#         <label class="inline">
#           <input class="sp-chkbox" type="radio" ng-model="searchCondition.pyeongType" value="0" name="pyeongType-type">
#           <span>建物</span>
#         </label>
#         <label class="inline">
#           <input class="sp-chkbox" type="radio" ng-model="searchCondition.pyeongType" value="1" name="pyeongType-type">
#           <span>土地</span>
#         </label>
#         <label class="inline">
#           <input class="sp-chkbox" type="radio" ng-model="searchCondition.pyeongType" value="2" name="pyeongType-type">
#           <span>主+陽</span>
#         </label>
#       </div>
#
#       <label>
#         <input type="checkbox" index="-1" listtype="pyeongList" class="chkbox chkbox-any" chkbox-area
#         ga-buy-search ga_action="buy_search_%%_sqft_click" ga_label="buy_search_%%_sqft_none" ga_cat="buy_search"><span>坪數不限</span>
#       </label>
#
#       <label ng-repeat="i in pyeongList">
#         <input type="checkbox" index="{{$index}}" listtype="pyeongList" class="chkbox" chkbox-area
#                ga-buy-search ga_action="buy_search_%%_sqft_click" ga_label="buy_search_%%_sqft_{{ pyeongList[$index - 1] || '' }}-{{ pyeongList[$index] || ''}}" ga_cat="buy_search">
#         <span ng-if=" $index == 0">{{ pyeongList[$index] }} 坪以下</span>
#         <span ng-if=" $index > 0 && $index < (pyeongList.length-1) ">{{ pyeongList[$index - 1] }} 坪 - {{ pyeongList[$index] }} 坪</span>
#         <span ng-if=" $index == (pyeongList.length - 1) ">{{ pyeongList[$index - 1] }} 坪以上</span>
#       </label>
#
#       <div class="custom-block">
#         <div class="input-wrap">
#           <input index="0" listtype="pyeongList" class="custom-num num" type="text" size="3"> -
#           <input index="1" listtype="pyeongList" class="custom-num num" type="text" size="3"> 坪
#         </div>
#       </div>
#     </div>
#   </div>
#
#   <!-- 關鍵字自動完成 -->
#   <span class="m-search-input-wrap">
#     <input type="text" class="search-text-keywords" data-channel="buy" placeholder="編號、關鍵字、街道、大樓或學校"><button class="search-text-query" ga-buy-search ga-label="buy_search_%%_keyword_btn" ga-event="buy_search_%%_keyword_click" ga-cat="buy_search"><i class="fa fa-search fa-lg"></i></button>
#     <div class="search-keywords-ac select-option">
#       <ul>
#         <li ng-repeat="k in autoComplete" class="search-auto-complete"  data-keyword="{{ k.KEYWORD }}">
#           <div class="keyword-title">{{ k.KEYWORD }}</div>
#           <div class="keyword-count">約 {{ k.COUNT }} 間</div>
#         </li>
#       </ul>
#     </div>
#   </span>
#
#   <a href class="search-more-fliter-switcher" ga-buy-search ga_action="buy_search_%%_click" ga_label="buy_search_%%_more" ga_cat="buy_search">更多篩選({{ more_filter_counter() }})</a>
#   <a href class="search-submit-btn" ga-buy-search ga_action="buy_search_%%_click" ga_label="buy_search_%%_btn" ga_cat="buy_search">找房子</a>
# </div> <!-- m-search-field -->
#
#
# <!-- 更多篩選條件 -->
# <div class="m-search-more-filter-block">
#   <div class="search-filter-block-wrap">
#
#     <!-- col1  -->
#     <div class="col" style="max-width: 129px;">
#       <div class="chkbox-wrap">
#         <label ng-repeat="i in advConditions.houseType.val">
#         <input type="checkbox" class="chkbox" value="{{i}}" listtype="houseType" simple-chkbox
#           ng-checked="searchCondsIsChecked('houseType', i, searchCondition.advConditions)"
#           ga-buy-search ga_action="buy_search_%%_type_click"
#           ga_label="buy_search_%%_type_{{i}}"
#           ga_cat="buy_search">
#         <span>{{ i }}</span></label>
#       </div>
#     </div>
#     <!-- col1  -->
#
#     <!-- col2  -->
#     <div class="col" style="max-width: 118px;">
#       <div class="chkbox-wrap">
#         <label
#           ng-hide="searchCondition.searchFor == 'earth'"
#           ng-repeat="i in advConditions.car.val">
#           <input type="checkbox" class="chkbox" value="{{i}}" listtype="car" simple-chkbox
#             ga-buy-search
#             ga_action="buy_search_%%_park_click"
#             ga_label="buy_search_%%_park_{{i}}"
#             ga_cat="buy_search"
#             ng-checked="searchCondsIsChecked('car', i, searchCondition.advConditions)">
#             <span>{{ (i === '庭院') ? '庭院/其他' : i }}</span>
#         </label>
#       </div>
#     </div>
#     <!-- col2  -->
#
#     <div class="col select-option" style="max-width: 154px;" ng-hide="searchCondition.searchFor == 'earth'">
#
#       <label>
#         <input type="checkbox" index="-1" listtype="houseAge" class="chkbox chkbox-any" chkbox-area
#           ga-buy-search
#           ga_action="buy_search_%%_age_click"
#           ga_label="buy_search_%%_age_none"
#           ga_cat="buy_search"><span> 屋齡不限</span>
#       </label>
#
#       <label ng-repeat="i in advConditions.houseAge.val">
#         <input type="checkbox" index="{{$index}}" listtype="houseAge" class="chkbox" chkbox-area
#                ga-buy-search
#                ga_action="buy_search_%%_age_click"
#                ga_cat="buy_search"
#                ga_label="buy_search_%%_age_{{ advConditions.houseAge.val[$index - 1] }}-{{ advConditions.houseAge.val[$index] }}"
#                ng-class="{ 'checkbox_sp' : $index == advConditions.houseAge.val.length - 1 }"
#                ng-checked="searchCondsIsChecked('houseAge', i, searchCondition.advConditions)">
#
#         <span ng-if=" $index == 0 ">預售屋</span>
#         <span ng-if=" $index == 1 ">{{ advConditions.houseAge.val[$index] }} 年以下</span>
#         <span ng-if=" $index > 1 && $index < (advConditions.houseAge.val.length-1) ">
#           {{ advConditions.houseAge.val[$index - 1] }} 年 - {{ advConditions.houseAge.val[$index] }} 年</span>
#         <span ng-if=" $index == (advConditions.houseAge.val.length - 1) ">{{ advConditions.houseAge.val[$index - 1] }} 年以上</span>
#       </label>
#
#       <div class="input-wrap">
#         <input index="0" listtype="houseAge" class="custom-num num" type="text" size="2"> -
#         <input index="1" listtype="houseAge" class="custom-num num" type="text" size="2"> 年
#       </div>
#     </div>
#
#     <div class="col select-option" style="max-width: 156px;" ng-hide="searchCondition.searchFor == 'earth'">
#       <label>
#       <input type="checkbox" index="-1" listtype="floors" class="chkbox chkbox-any" chkbox-area
#         ga-buy-search
#         ga_action="buy_search_%%_floor_click"
#         ga_label="buy_search_%%_floor_none"
#         ga_cat="buy_search"><span> 樓層不限</span></label>
#
#       <label ng-repeat="i in advConditions.floors.val" ng-if="$index != 3 && $index != 5">
#         <input type="checkbox" index="{{$index}}" listtype="floors" class="chkbox" chkbox-area
#           ng-class="{ 'checkbox_sp' : $index == advConditions.floors.val.length - 1 }"
#           ng-checked="searchCondsIsChecked('floors', i, searchCondition.advConditions)"
#           ga-buy-search
#           ga_action="buy_search_%%_floor_click"
#           ga_label="buy_search_%%_floor_{{ advConditions.floors.val[$index] }}-{{ advConditions.floors.val[$index+1] }}"
#           ga_cat="buy_search">
#
#         <span ng-if="$index == 0" data-min="0" data-max="0">低於 1 樓</span>
#         <span ng-if="$index == 1" data-min="{{advConditions.floors.val[$index]}}" data-max="{{advConditions.floors.val[$index]}}">
#         {{ advConditions.floors.val[$index] }} 樓</span>
#
#         <span ng-if="$index > 1 && $index < (advConditions.floors.val.length-2)"
#               data-min="{{ advConditions.floors.val[$index] }}"
#               data-max="{{ advConditions.floors.val[$index+1] }}">
#           {{ advConditions.floors.val[$index] }} - {{ advConditions.floors.val[$index+1] }} 樓</span>
#
#         <span ng-if="$index == advConditions.floors.val.length - 2" data-min="{{ advConditions.floors.val[$index] }}" data-max="99">{{ advConditions.floors.val[$index] }} 樓以上</span>
#
#         <span ng-if="$index == advConditions.floors.val.length - 1">限頂樓</span>
#       </label>
#
#       <div class="input-wrap">
#         <input index="0" listtype="floors" class="custom-num num" type="text" size="2"> -
#         <input index="1" listtype="floors" class="custom-num num" type="text" size="2"> 樓
#       </div>
#     </div>
#
#     <div class="col select-option" style="max-width: 153px;" ng-hide="searchCondition.searchFor == 'parking' || searchCondition.searchFor == 'earth'">
#
#       <label><input type="checkbox" index="-1" listtype="rooms" class="chkbox chkbox-any" chkbox-area
#         ga-buy-search ga_action="buy_search_%%_room_click" ga_label="buy_search_%%_room_none" ga_cat="buy_search"><span> 房數不限</span></label>
#
#       <label ng-repeat="i in advConditions.rooms.val">
#         <input type="checkbox" index="{{$index}}" listtype="rooms" class="chkbox" chkbox-area
#           ng-checked="searchCondsIsChecked('rooms', i, searchCondition.advConditions)"
#           ng-class="{ 'checkbox_sp' : $index == advConditions.rooms.val.length-1 }"
#           ga-buy-search
#           ga_action="buy_search_%%_room_click"
#           ga_label="buy_search_%%_room_{{ advConditions.rooms.val[$index] }}"
#           ga_cat="buy_search">
#
#         <span ng-if="$index == 0"> 1房(含套房)</span>
#         <span ng-if="$index >0 && $index < advConditions.rooms.val.length - 1 && $index != advConditions.rooms.val.length-2">
#         {{ advConditions.rooms.val[$index] }} 房</span>
#
#         <span ng-if="$index == advConditions.rooms.val.length-2"> {{ advConditions.rooms.val[$index] }} 房以上</span>
#         <span ng-if="$index == advConditions.rooms.val.length-1"> 含加蓋</span>
#       </label>
#
#       <div class="input-wrap">
#         <input index="0" listtype="rooms" class="custom-num num" type="text" size="2"> -
#         <input index="1" listtype="rooms" class="custom-num num" type="text" size="2"> 房
#       </div>
#     </div>
#
#     <div class="col" style="max-width: 100px;"
#       ng-hide="searchCondition.searchFor == 'parking' || searchCondition.searchFor == 'earth'">
#       <div class="chkbox-wrap">
#         <label ng-repeat="i in advConditions.directions.val">
#           <input type="checkbox" class="chkbox" value="{{i}}" listtype="directions" simple-chkbox
#             ng-checked="searchCondsIsChecked('directions', i, searchCondition.advConditions)"
#             ga-buy-search
#             ga_action="buy_search_%%_toward_click"
#             ga_label="buy_search_%%_toward_{{i}}"
#             ga_cat="buy_search">
#           <span ng-if=" $index == 0 ">朝向{{ i }}</span>
#           <span ng-if=" $index > 0 ">{{ i }}</span>
#         </label>
#       </div>
#     </div>
#
#     <div class="col"  style="max-width: 91px;"
#          ng-hide="searchCondition.searchFor == 'parking' || searchCondition.searchFor == 'earth'">
#       <div class="chkbox-wrap">
#         <label ng-repeat="i in advConditions.sp.val">
#           <input type="checkbox" class="chkbox" value="{{i}}" listtype="sp" simple-chkbox
#             ng-checked="searchCondsIsChecked('sp', i, searchCondition.advConditions)"
#             ga-buy-search
#             ga_action="buy_search_%%_sp_click"
#             ga_label="buy_search_%%_sp_{{i}}"
#             ga_cat="buy_search">
#           <span>{{ i }}</span>
#         </label>
#
#         <label ng-repeat="i in advConditions.accessible.val">
#           <input type="checkbox" class="chkbox" value="{{i}}" listtype="accessible" simple-chkbox
#             ng-checked="searchCondsIsChecked('accessible', i, searchCondition.advConditions)"
#             ga-buy-search
#             ga_action="buy_search_%%_sp_click"
#             ga_label="buy_search_%%_sp_accessible_yes"
#             ga_cat="buy_search">
#           <span>{{ i }}</span>
#         </label>
#       </div>
#     </div>
#
#   </div>
# </div> <!-- .m-search-more-filter-block -->
#
#
# <!--  捷運地圖 -->
# <div ng-show="mainSelectOption.key == 'mrt'" class="mrt-map-handler-bar">
#   <a href class="mrt-map-handler on"></a>
# </div>
#
# <div ng-show="mainSelectOption.key == 'mrt'" class="m-mrt-map">
#   <div class="route-map">
#     <div class="mrt-stations-chkbox"
#          ng-class="{ 'tp-mrt-stations': searchCondition.addr[0][0] != '台中市' && searchCondition.addr[0][0] != '高雄市', 'tc-mrt-stations': searchCondition.addr[0][0] == '台中市' , 'kh-mrt-stations': searchCondition.addr[0][0] == '高雄市'}">
#       <span ng-show="searchCondition.addr[0][0] != '台中市' && searchCondition.addr[0][0] != '高雄市'"
#             ng-class="{'is-checked': searchCondition.mrt.indexOf(m.name) > -1 }"
#             ng-repeat="m in mrt.tp" class="mrt-chkbox" title="{{ m.name }}"
#             ng-style="m.css_coordinate"></span>
#
#       <span ng-show="searchCondition.addr[0][0] == '台中市'"
#             ng-class="{'is-checked': searchCondition.mrt.indexOf(m.name) > -1 }"
#             ng-repeat="m in mrt.tc" class="mrt-chkbox" title="{{ m.name }}"
#             ng-style="m.css_coordinate"></span>
#
#       <span ng-show="searchCondition.addr[0][0] == '高雄市'"
#             ng-class="{'is-checked': searchCondition.mrt.indexOf(m.name) > -1 }"
#             ng-repeat="m in mrt.kh" class="mrt-chkbox" title="{{ m.name }}"
#             ng-style="m.css_coordinate"></span>
#     </div>
#
#     <a href class="arrow arrow-up"></a>
#     <a href class="arrow arrow-down"></a>
#   </div>
# </div>
#
# </div> <!-- ng-search-bar -->
# <!-- 搜尋區塊 -->    <!-- 搜尋區塊 -->
#     <!-- 推薦物件 -->
#     <section class="m-main-block ng-scope">
#         <header class="main-block-hd has-line">
#             <h2>本週必搶</h2>
#         </header>
#         <div class="main-block-bd">
#             <ul pagetype="buylist" class="l-item-list promo-list ng-isolate-scope is-loading"></ul>
#         </div>
#     </section>
#     <!-- 推薦物件 -->
#     <!-- 物件列表 -->
#     <div class="l-main-list">
#         <div class="list-hd-outer">
#             <div class="list-type">
#                 <a ga-buy-search ga-label="buy_function_list_button" ga-event="buy_function_click" ga-cat="buy_function" href="#" class="list-text active"><i class="fa fa-list-ul"></i> 列表</a>
#                 <a ga-buy-search ga-label="buy_function_map_button" ga-event="buy_function_click" ga-cat="buy_function" href="#" class="list-map"><i class="i-map"></i> 地圖</a>
#             </div>
#
#         </div>
#
#         <!-- <div class="list-filters"> -->
# <div class="list-hd-inner">
#     <a href ga-buy-search filter="" class="list-filter is-first gtmPushEvent active" event="click_item" block_name="$channel_$searchType_filtertag" term="全部"><span>全部 (5278)</span></a>
#     <a href ga-buy-search filter="newyouth" class="list-filter highlight gtmPushEvent " event="click_item" block_name="$channel_$searchType_filtertag" term="新青安推薦"><span>新青安推薦 (1100)</span></a>
#     <a href ga-buy-search filter="vr" class="list-filter gtmPushEvent " event="click_item" block_name="$channel_$searchType_filtertag" term="實境找房"><span>實境找房 (2546)</span></a>
#     <a href ga-buy-search filter="new" class="list-filter gtmPushEvent " event="click_item" block_name="$channel_$searchType_filtertag" term="新上架"><span>新上架 (641)</span></a>
#     <a href ga-buy-search filter="pricereduction" class="list-filter downPrice gtmPushEvent   YC" event="click_item" block_name="$channel_$searchType_filtertag" term="降價專區"><span>降價專區 (1682)</span></a>
#     <div class="list-sort-type m-select-box-wrap">
#     <a href class="list-sort-handler m-select-box">預設排序</a>
#     <div class="m-select-box-option has-border arrow-right">
#         <a href class="list-sort-option label gtmPushEvent" data-od="" ga-buy-search event="click_item" block_name="$channel_$searchType_sort" term="預設排序">預設排序</a>
#
#     <a href class="list-sort-option label gtmPushEvent" data-od="11" ga-buy-search event="click_item" block_name="$channel_$searchType_sort" term="總價低→高">總價: <span class="right">低 → 高</span></a>
#     <a href class="list-sort-option label gtmPushEvent" data-od="21" ga-buy-search event="click_item" block_name="$channel_$searchType_sort" term="單價低→高">單價: <span class="right">低 → 高</span></a>
#     <a href class="list-sort-option label gtmPushEvent" data-od="30" ga-buy-search event="click_item" block_name="$channel_$searchType_sort" term="降幅高→低">降幅: <span class="right">高 → 低</span></a>
#     <a href class="list-sort-option label gtmPushEvent" data-od="40" ga-buy-search event="click_item" block_name="$channel_$searchType_sort" term="建坪大→小">建坪: <span class="right">大 → 小</span></a>
#     <a href class="list-sort-option label gtmPushEvent" data-od="50" ga-buy-search event="click_item" block_name="$channel_$searchType_sort" term="主+陽大→小">主+陽: <span class="right">大 → 小</span></a>
#     <a href class="list-sort-option label gtmPushEvent" data-od="61" ga-buy-search event="click_item" block_name="$channel_$searchType_sort" term="屋齡小→大">屋齡: <span class="right">小 → 大</span></a>
#     <a href class="list-sort-option label gtmPushEvent" data-od="70" ga-buy-search event="click_item" block_name="$channel_$searchType_sort" term="地坪大→小">地坪: <span class="right">大 → 小</span></a>
#     <a href class="list-sort-option label gtmPushEvent" data-od="80" ga-buy-search event="click_item" block_name="$channel_$searchType_sort" term="上架日期新→舊">上架日期: <span class="right">新 → 舊</span></a>
#     </div>
# </div>
#
#
# </div>
#
#
#         <!-- 主列表 -->
#             <ul class="l-item-list">
#
#
#
#
#
#
#
#
#
# <li class="m-list-item">
# <i class="is-vr"></i>        <i class="is-docent-video"></i>    <a href="/house/6285237" class="item-img gtmPushEvent" event="select_item" block_name="$channel_$searchType_result" term="pic" item_id="6285237" title="天母靜好2房車位 台北市士林區中山北路六段" target="_blank">
#         <figure class="img-wrap"><img src="//yccdn.yungching.com.tw/v1/image/?key=NF58Ko5oaCsMM5ZuNBXrautiyPELIvNgAoALCtT4VfbLqkYL4543txxi6AiVkGBUqVhtUUJ4lA_cF1mBh5MY1RWd5eEaa7mn9qxu8f6s-rtKfVoBsurTgAnsNQ3b1ueVa0jD0JJgeWt02Xc92Hgeax9ptXAdU5ZuHyqQdxAoaDgB84hAAJBJ-aPJnP6QjjHNJdO-8s9VPXXQ_ruSEFqcK8ShYsvown2RKluDB4vs3XCba78wTuCNPINc3dOPPQMQruh-Gt23mTzaYgmqa__ngegw_kxkxkdM5Y2LgriectG9txh5JQn0mw&amp;width=480&amp;height=0" onerror="this.src='/Content/img/non-photo.png';" alt="天母靜好2房車位 台北市士林區中山北路六段"></figure>
#     </a>
#     <div class="item-info">
#         <a href="/house/6285237" target="_blank" class="item-title gtmPushEvent" title="天母靜好2房車位 台北市士林區中山北路六段" event="select_item" block_name="$channel_$searchType_result" term="name" item_id="6285237">
#             <h3>天母靜好2房車位</h3>
#                                 </a>
#             <div class="item-description" ng-non-bindable><span style="font-weight: 700; color: #666; margin-right: 1em;">台北市士林區中山北路六段</span><span> 平面車位.本層只有2戶 </span></div>
#         <ul class="item-info-detail" style="height: auto">
#             <li>住宅大樓</li>
#             <li>
# 2.1年            </li>
#             <li>
# 2 ~ 2 / 14樓            </li>
#             <li>土地 5.55坪</li>
#                     <li>主+陽 16.35坪</li>
#             <li>建物 40.19坪</li>
#             <li>
# 2房(室)2廳1衛            </li>
#             <li>
#             </li>
#             <li>
# (含車位12.33坪)            </li>
#         </ul>
#
#         <div class="item-tags">
#             <i class="fa fa-tags"></i>
#                                 <span>新上</span>
#                                     <span>天母靜好</span>
#                         <span>近捷運蘭雅(未通車)站</span>
#                         <span>近捷運芝山站</span>
#                         <span>有天然瓦斯</span>
#             <span>永慶房屋</span>
#         </div>
#     </div>
#
#     <div class="item-price">
#         <div class="price"><span class="price-num">3,342</span> 萬</div>
# <div class="sub-price">(含車位價)</div>        <div class="sub-price"></div>
#
#             <a href="/house/6285237?vrmode=1" target="_blank" class="view-vr-btn gtmPushEvent" event="select_item" block_name="$channel_$searchType_result" term="vr" item_id="6285237">看實境</a>
#         <a ga-buy-search href class="save-not-login-btn save-item-btn gtmPushEvent" event="add_to_wishlist" block_name="$channel_$searchType_result" term="housefollow" item_id="6285237" data-favo data-favo-pop data-caseid="adb1d590-1eff-42a1-86ba-9977e9b7be43">降價通知</a>
#     </div>
# </li>
#
#
#
#
#
#
#
#
# <li class="m-list-item">
# <i class="is-vr"></i>        <i class="is-docent-video"></i>    <a href="/house/6310802" class="item-img gtmPushEvent" event="select_item" block_name="$channel_$searchType_result" term="pic" item_id="6310802" title="高樓美景甲大直 台北市中山區北安路" target="_blank">
#         <figure class="img-wrap"><img src="//yccdn.yungching.com.tw/v1/image/?key=NF58Ko5oaCtoKidNSDUU-uZT1ODIbeEsDzgAkQXKRQb3wE--Tizfimx5WE3kiOtdqVhtUUJ4lA_cF1mBh5MY1RWd5eEaa7mn9qxu8f6s-rtKfVoBsurTgAnsNQ3b1ueVa0jD0JJgeWt02Xc92Hgeax9ptXAdU5ZuHyqQdxAoaDgB84hAAJBJ-aPJnP6QjjHNJdO-8s9VPXXQ_ruSEFqcK8ShYsvown2RbJENeZqhwTM&amp;width=480&amp;height=0" onerror="this.src='/Content/img/non-photo.png';" alt="高樓美景甲大直 台北市中山區北安路"></figure>
#     </a>
#     <div class="item-info">
#         <a href="/house/6310802" target="_blank" class="item-title gtmPushEvent" title="高樓美景甲大直 台北市中山區北安路" event="select_item" block_name="$channel_$searchType_result" term="name" item_id="6310802">
#             <h3>高樓美景甲大直</h3>
#                                 </a>
#             <div class="item-description" ng-non-bindable><span style="font-weight: 700; color: #666; margin-right: 1em;">台北市中山區北安路</span><span> 機能便利高樓景觀戶稀有釋出 </span></div>
#         <ul class="item-info-detail" style="height: auto">
#             <li>住宅大樓</li>
#             <li>
# 20.4年            </li>
#             <li>
# 9 ~ 9 / 14樓            </li>
#             <li>土地 5.01坪</li>
#                     <li>主+陽 23.18坪</li>
#             <li>建物 45.14坪</li>
#             <li>
# 1房(室)2廳2衛            </li>
#             <li>
#             </li>
#             <li>
# (含車位11.92坪)            </li>
#                 <li>
#                     坡道平面車位
#                 </li>
#         </ul>
#
#         <div class="item-tags">
#             <i class="fa fa-tags"></i>
#                                 <span>新上</span>
#                                     <span>甲大直</span>
#                         <span>近捷運大直站</span>
#                         <span>有天然瓦斯</span>
#             <span>永慶房屋</span>
#         </div>
#     </div>
#
#     <div class="item-price">
#         <div class="price"><span class="price-num">4,780</span> 萬</div>
# <div class="sub-price">(含車位價)</div>        <div class="sub-price"></div>
#
#             <a href="/house/6310802?vrmode=1" target="_blank" class="view-vr-btn gtmPushEvent" event="select_item" block_name="$channel_$searchType_result" term="vr" item_id="6310802">看實境</a>
#         <a ga-buy-search href class="save-not-login-btn save-item-btn gtmPushEvent" event="add_to_wishlist" block_name="$channel_$searchType_result" term="housefollow" item_id="6310802" data-favo data-favo-pop data-caseid="0517de68-4978-4434-96c4-4baaf1638c6c">降價通知</a>
#     </div>
# </li>
#
#
#
#
#
#
#
#
# <li class="m-list-item">
# <i class="is-vr"></i>    <i class="is-render"></i>    <i class="is-docent-video"></i>    <a href="/house/5246176" class="item-img gtmPushEvent" event="select_item" block_name="$channel_$searchType_result" term="pic" item_id="5246176" title="極美山景三房車 台北市文山區富山路" target="_blank">
#         <figure class="img-wrap"><img src="//yccdn.yungching.com.tw/v1/image/?key=NF58Ko5oaCvyfJsir1QuHtFsNOmLTtYLVDzUvymPTsoGzhSyeoIWeTDC_Ra-EynWqVhtUUJ4lA_cF1mBh5MY1RWd5eEaa7mn9qxu8f6s-rtKfVoBsurTgAnsNQ3b1ueVa0jD0JJgeWt02Xc92Hgeax9ptXAdU5ZuHyqQdxAoaDgB84hAAJBJ-aPJnP6QjjHNJdO-8s9VPXXQ_ruSEFqcK8ShYsvown2RbJENeZqhwTM&amp;width=480&amp;height=0" onerror="this.src='/Content/img/non-photo.png';" alt="極美山景三房車 台北市文山區富山路"></figure>
#     </a>
#     <div class="item-info">
#         <a href="/house/5246176" target="_blank" class="item-title gtmPushEvent" title="極美山景三房車 台北市文山區富山路" event="select_item" block_name="$channel_$searchType_result" term="name" item_id="5246176">
#             <h3>極美山景三房車</h3>
#                                 </a>
#             <div class="item-description" ng-non-bindable><span style="font-weight: 700; color: #666; margin-right: 1em;">台北市文山區富山路</span><span> 清新美景質感社區永建學區 </span></div>
#         <ul class="item-info-detail" style="height: auto">
#             <li>華廈</li>
#             <li>
# 15.4年            </li>
#             <li>
# 4 ~ 4 / 7樓            </li>
#             <li>土地 11.91坪</li>
#                     <li>主+陽 29.45坪</li>
#             <li>建物 62.21坪</li>
#             <li>
# 3房(室)2廳3衛            </li>
#             <li>
# 含加蓋 0房(室)0廳1衛            </li>
#             <li>
# (含車位11.19坪)            </li>
#                 <li>
#                     坡道機械車位
#                 </li>
#         </ul>
#
#         <div class="item-tags">
#             <i class="fa fa-tags"></i>
#                                                 <span>清新美景</span>
#                         <span>近捷運考試院站(規劃中)</span>
#                         <span>近捷運興隆路站(規劃中)</span>
#                         <span>有天然瓦斯</span>
#             <span>永慶房屋</span>
#         </div>
#     </div>
#
#     <div class="item-price">
#             <div class="reduce-rate">7.9%</div>
#             <div class="original-price"> 3,888 萬</div>
#         <div class="price"><span class="price-num">3,580</span> 萬</div>
# <div class="sub-price">(含車位價)</div>        <div class="sub-price"></div>
#
#             <a href="/house/5246176?vrmode=1" target="_blank" class="view-vr-btn gtmPushEvent" event="select_item" block_name="$channel_$searchType_result" term="vr" item_id="5246176">看實境</a>
#         <a ga-buy-search href class="save-not-login-btn save-item-btn gtmPushEvent" event="add_to_wishlist" block_name="$channel_$searchType_result" term="housefollow" item_id="5246176" data-favo data-favo-pop data-caseid="f86d53c3-317e-4e9d-b7f7-97716a999358">降價通知</a>
#     </div>
# </li>
#
#
#
#
#
#
#
#
# <li class="m-list-item">
# <i class="is-vr"></i>    <i class="is-render"></i>    <i class="is-docent-video"></i>    <a href="/house/6314788" class="item-img gtmPushEvent" event="select_item" block_name="$channel_$searchType_result" term="pic" item_id="6314788" title="大安名人華廈3房 台北市大安區仁愛路四段" target="_blank">
#         <figure class="img-wrap"><img src="//yccdn.yungching.com.tw/v1/image/?key=NF58Ko5oaCt8eRnyPDAcwIlYC07OTQwwvSfoUqa5UqQKB6ujBQA05wT95R5EdU4zqVhtUUJ4lA_cF1mBh5MY1RWd5eEaa7mn9qxu8f6s-rtKfVoBsurTgAnsNQ3b1ueVa0jD0JJgeWt02Xc92Hgeax9ptXAdU5ZuHyqQdxAoaDgB84hAAJBJ-aPJnP6QjjHNJdO-8s9VPXXQ_ruSEFqcK8ShYsvown2RbJENeZqhwTM&amp;width=480&amp;height=0" onerror="this.src='/Content/img/non-photo.png';" alt="大安名人華廈3房 台北市大安區仁愛路四段"></figure>
#     </a>
#     <div class="item-info">
#         <a href="/house/6314788" target="_blank" class="item-title gtmPushEvent" title="大安名人華廈3房 台北市大安區仁愛路四段" event="select_item" block_name="$channel_$searchType_result" term="name" item_id="6314788">
#             <h3>大安名人華廈3房</h3>
#                                 </a>
#             <div class="item-description" ng-non-bindable><span style="font-weight: 700; color: #666; margin-right: 1em;">台北市大安區仁愛路四段</span><span> SOGO生活圈靜巷棟距大 </span></div>
#         <ul class="item-info-detail" style="height: auto">
#             <li>華廈</li>
#             <li>
# 45.4年            </li>
#             <li>
# 3 ~ 3 / 6樓            </li>
#             <li>土地 8.51坪</li>
#                     <li>主+陽 36.19坪</li>
#             <li>建物 41.26坪</li>
#             <li>
# 3房(室)2廳2衛            </li>
#             <li>
#             </li>
#             <li>
#             </li>
#         </ul>
#
#         <div class="item-tags">
#             <i class="fa fa-tags"></i>
#                                 <span>新上</span>
#                                     <span>家齊大廈</span>
#                         <span>近捷運忠孝復興站</span>
#                         <span>近捷運大安站</span>
#             <span>永慶房屋</span>
#         </div>
#     </div>
#
#     <div class="item-price">
#         <div class="price"><span class="price-num">4,950</span> 萬</div>
#         <div class="sub-price"></div>
#
#             <a href="/house/6314788?vrmode=1" target="_blank" class="view-vr-btn gtmPushEvent" event="select_item" block_name="$channel_$searchType_result" term="vr" item_id="6314788">看實境</a>
#         <a ga-buy-search href class="save-not-login-btn save-item-btn gtmPushEvent" event="add_to_wishlist" block_name="$channel_$searchType_result" term="housefollow" item_id="6314788" data-favo data-favo-pop data-caseid="38909caf-8774-47df-84aa-e54e9ec85222">降價通知</a>
#     </div>
# </li>
#
#
#
#
#
#
#
#
# <li class="m-list-item">
# <i class="is-vr"></i>    <i class="is-render"></i>    <i class="is-docent-video"></i>    <a href="/house/6173830" class="item-img gtmPushEvent" event="select_item" block_name="$channel_$searchType_result" term="pic" item_id="6173830" title="昇陽美妝邊間8樓 台北市大安區光復南路" target="_blank">
# ...
#         <figure class="img-wrap"><img src="//yccdn.yungching.com.tw/v1/image/?key=NF58Ko5oaCvYQUlGcyNDmsM9Y1E-nSwh34PcVBbGnLuNBlJhRtrDNsSiufCIHynzqVhtUUJ4lA_cF1mBh5MY1RWd5eEaa7mn9qxu8f6s-rtKfVoBsurTgAnsNQ3b1ueVa0jD0JJgeWt02Xc92Hgeax9ptXAdU5ZuHyqQdxAoaDgB84hAAJBJ-aPJnP6QjjHNJdO-8s9VPXXQ_ruSEFqcK8ShYsvown2RKluDB4vs3XCba78wTuCNPINc3dOPPQMQ7B1phpHz8Gf1IwmTkNi-8egw_kxkxkdM5Y2LgriectG9txh5JQn0mw&amp;width=480&amp;height=0" onerror="this.src='/Content/img/non-photo.png';" alt="天母磺溪三房坡車 台北市士林區天母北路"></figure>
#     </a>
#     <div class="item-info">
#         <a href="/house/5814391" target="_blank" class="item-title gtmPushEvent" title="天母磺溪三房坡車 台北市士林區天母北路" event="select_item" block_name="$channel_$searchType_result" term="name" item_id="5814391">
#             <h3>天母磺溪三房坡車</h3>
#                                 </a>
#             <div class="item-description" ng-non-bindable><span style="font-weight: 700; color: #666; margin-right: 1em;">台北市士林區天母北路</span><span> 天母磺溪畔，豪華逸居生活。 </span></div>
#         <ul class="item-info-detail" style="height: auto">
#             <li>住宅大樓</li>
#             <li>
# 43.1年            </li>
#             <li>
# 5 ~ 5 / 11樓            </li>
#             <li>土地 9.95坪</li>
#                     <li>主+陽 45.08坪</li>
#             <li>建物 65.74坪</li>
#             <li>
# 3房(室)2廳2衛            </li>
#             <li>
#             </li>
#             <li>
# (含車位12.19坪)            </li>
#                 <li>
#                     坡道平面車位
#                 </li>
#         </ul>
#
#         <div class="item-tags">
#             <i class="fa fa-tags"></i>
#                                                 <span>石濤園</span>
#                         <span>有天然瓦斯</span>
#             <span>永慶房屋</span>
#         </div>
#     </div>
#
#     <div class="item-price">
#             <div class="reduce-rate">8.2%</div>
#             <div class="original-price"> 4,988 萬</div>
#         <div class="price"><span class="price-num">4,580</span> 萬</div>
# <div class="sub-price">(含車位價)</div>        <div class="sub-price"></div>
#
#             <a href="/house/5814391?vrmode=1" target="_blank" class="view-vr-btn gtmPushEvent" event="select_item" block_name="$channel_$searchType_result" term="vr" item_id="5814391">看實境</a>
#         <a ga-buy-search href class="save-not-login-btn save-item-btn gtmPushEvent" event="add_to_wishlist" block_name="$channel_$searchType_result" term="housefollow" item_id="5814391" data-favo data-favo-pop data-caseid="e4560abd-e3f1-48c3-afcc-a189686037f5">降價通知</a>
#     </div>
# </li>
#
#
#
#
#
#
#
#
# <li class="m-list-item">
# <i class="is-vr"></i>        <i class="is-docent-video"></i>    <a href="/house/6078056" class="item-img gtmPushEvent" event="select_item" block_name="$channel_$searchType_result" term="pic" item_id="6078056" title="大直江山裝潢美邸 台北市內湖區內湖路一段" target="_blank">
#         <figure class="img-wrap"><img src="//yccdn.yungching.com.tw/v1/image/?key=NF58Ko5oaCsdW6TsATz6PG4o00-kOy3wLA98jd9AI-czSWF8VMSZSqL3jZqZRPDPqVhtUUJ4lA_cF1mBh5MY1RWd5eEaa7mn9qxu8f6s-rtKfVoBsurTgAnsNQ3b1ueVa0jD0JJgeWt02Xc92Hgeax9ptXAdU5ZuHyqQdxAoaDgB84hAAJBJ-aPJnP6QjjHNJdO-8s9VPXXQ_ruSEFqcK8ShYsvown2RbJENeZqhwTM&amp;width=480&amp;height=0" onerror="this.src='/Content/img/non-photo.png';" alt="大直江山裝潢美邸 台北市內湖區內湖路一段"></figure>
#     </a>
#     <div class="item-info">
#         <a href="/house/6078056" target="_blank" class="item-title gtmPushEvent" title="大直江山裝潢美邸 台北市內湖區內湖路一段" event="select_item" block_name="$channel_$searchType_result" term="name" item_id="6078056">
#             <h3>大直江山裝潢美邸</h3>
#                                 </a>
#             <div class="item-description" ng-non-bindable><span style="font-weight: 700; color: #666; margin-right: 1em;">台北市內湖區內湖路一段</span><span> 位靜巷,近美麗華,有裝潢有車位 </span></div>
#         <ul class="item-info-detail" style="height: auto">
#             <li>華廈</li>
#             <li>
# 33.8年            </li>
#             <li>
# 5 ~ 5 / 5樓            </li>
#             <li>土地 14.19坪</li>
#                     <li>主+陽+露 47.37坪</li>
#             <li>建物 62.67坪</li>
#             <li>
# 7房(室)3廳4衛            </li>
#             <li>
# 含加蓋 2房(室)1廳1衛            </li>
#             <li>
# (含車位10.31坪)            </li>
#                 <li>
#                     坡道平面車位
#                 </li>
#         </ul>
#
#         <div class="item-tags">
#             <i class="fa fa-tags"></i>
#                                                 <span>大直江山</span>
#                         <span>近捷運劍南路站</span>
#                         <span>近捷運下塔悠站(規劃中)</span>
#                         <span>有天然瓦斯</span>
#             <span>永慶房屋</span>
#         </div>
#     </div>
#
#     <div class="item-price">
#         <div class="price"><span class="price-num">4,998</span> 萬</div>
# <div class="sub-price">(含車位價)</div>        <div class="sub-price"></div>
#
#             <a href="/house/6078056?vrmode=1" target="_blank" class="view-vr-btn gtmPushEvent" event="select_item" block_name="$channel_$searchType_result" term="vr" item_id="6078056">看實境</a>
#         <a ga-buy-search href class="save-not-login-btn save-item-btn gtmPushEvent" event="add_to_wishlist" block_name="$channel_$searchType_result" term="housefollow" item_id="6078056" data-favo data-favo-pop data-caseid="cd554bcb-3c72-4826-9672-7db49cae9322">降價通知</a>
#     </div>
# </li>
#
#
#
#
#
#
#
#
# <li class="m-list-item">
# <i class="is-vr"></i>    <i class="is-render"></i>    <i class="is-docent-video"></i>    <a href="/house/5204248" class="item-img gtmPushEvent" event="select_item" block_name="$channel_$searchType_result" term="pic" item_id="5204248" title="森林公園挑高一樓 台北市中正區臨沂街" target="_blank">
#         <figure class="img-wrap"><img src="//yccdn.yungching.com.tw/v1/image/?key=NF58Ko5oaCtWVoUspqEvCYCfiHHsYwunS17AzV6S34Tep-ZaiqKck7SHNF_vXNvmqVhtUUJ4lA_cF1mBh5MY1RWd5eEaa7mn9qxu8f6s-rtKfVoBsurTgAnsNQ3b1ueVa0jD0JJgeWt02Xc92Hgeax9ptXAdU5ZuHyqQdxAoaDgB84hAAJBJ-aPJnP6QjjHNJdO-8s9VPXXQ_ruSEFqcK8ShYsvown2RbJENeZqhwTM&amp;width=480&amp;height=0" onerror="this.src='/Content/img/non-photo.png';" alt="森林公園挑高一樓 台北市中正區臨沂街"></figure>
#     </a>
#     <div class="item-info">
#         <a href="/house/5204248" target="_blank" class="item-title gtmPushEvent" title="森林公園挑高一樓 台北市中正區臨沂街" event="select_item" block_name="$channel_$searchType_result" term="name" item_id="5204248">
#             <h3>森林公園挑高一樓</h3>
#                                 </a>
#             <div class="item-description" ng-non-bindable><span style="font-weight: 700; color: #666; margin-right: 1em;">台北市中正區臨沂街</span><span> 東門捷運站金華國中永康街大安森 </span></div>
#         <ul class="item-info-detail" style="height: auto">
#             <li>華廈</li>
#             <li>
# 35.9年            </li>
#             <li>
# B1 ~ 1 / 6樓            </li>
#             <li>土地 15.76坪</li>
#                     <li>主+平 33.59坪</li>
#             <li>建物 59.03坪</li>
#             <li>
# 2房(室)3廳2衛            </li>
#             <li>
#             </li>
#             <li>
#             </li>
#         </ul>
#
#         <div class="item-tags">
#             <i class="fa fa-tags"></i>
#                                                 <span>近捷運東門站</span>
#                         <span>近捷運大安森林公園站</span>
#                         <span>有天然瓦斯</span>
#             <span>永慶房屋</span>
#         </div>
#     </div>
#
#     <div class="item-price">
#             <div class="reduce-rate">10.7%</div>
#             <div class="original-price"> 7,380 萬</div>
#         <div class="price"><span class="price-num">6,588</span> 萬</div>
#         <div class="sub-price"></div>
#
#             <a href="/house/5204248?vrmode=1" target="_blank" class="view-vr-btn gtmPushEvent" event="select_item" block_name="$channel_$searchType_result" term="vr" item_id="5204248">看實境</a>
#         <a ga-buy-search href class="save-not-login-btn save-item-btn gtmPushEvent" event="add_to_wishlist" block_name="$channel_$searchType_result" term="housefollow" item_id="5204248" data-favo data-favo-pop data-caseid="8e1dacc4-4ee0-4d5c-a988-bd7655dd6832">降價通知</a>
#     </div>
# </li>            </ul>
#
#         <div class="search-list-not-found"></div>
#             <div class="m-pagination">
#         <ul class="m-pagination-bd">
#                 <li class="is-disabled"><a href="" class="ga_click_trace" ga_cat="buy_page" ga_event="buy_page_click" ga_label="buy_page_first">第一頁</a></li>
#                 <li class="is-disabled"><a href="" class="ga_click_trace" ga_cat="buy_page" ga_event="buy_page_click" ga_label="buy_page_pre">&lt; 上一頁 </a></li>
#                     <li class="is-active"><a href="/region?pg=1" class="ga_click_trace" ga_cat="buy_page" ga_event="buy_page_click" ga_label="buy_page_1">1</a></li>
#                     <li class=""><a href="/region?pg=2" class="ga_click_trace" ga_cat="buy_page" ga_event="buy_page_click" ga_label="buy_page_2">2</a></li>
#                     <li class=""><a href="/region?pg=3" class="ga_click_trace" ga_cat="buy_page" ga_event="buy_page_click" ga_label="buy_page_3">3</a></li>
#                     <li class=""><a href="/region?pg=4" class="ga_click_trace" ga_cat="buy_page" ga_event="buy_page_click" ga_label="buy_page_4">4</a></li>
#                     <li class=""><a href="/region?pg=5" class="ga_click_trace" ga_cat="buy_page" ga_event="buy_page_click" ga_label="buy_page_5">5</a></li>
#                     <li class=""><a href="/region?pg=6" class="ga_click_trace" ga_cat="buy_page" ga_event="buy_page_click" ga_label="buy_page_6">6</a></li>
#                     <li class=""><a href="/region?pg=7" class="ga_click_trace" ga_cat="buy_page" ga_event="buy_page_click" ga_label="buy_page_7">7</a></li>
#                     <li class=""><a href="/region?pg=8" class="ga_click_trace" ga_cat="buy_page" ga_event="buy_page_click" ga_label="buy_page_8">8</a></li>
#                     <li class=""><a href="/region?pg=9" class="ga_click_trace" ga_cat="buy_page" ga_event="buy_page_click" ga_label="buy_page_9">9</a></li>
#                     <li class=""><a href="/region?pg=10" class="ga_click_trace" ga_cat="buy_page" ga_event="buy_page_click" ga_label="buy_page_10">10</a></li>
#                 <li class=""><a href="/region?pg=2" class="ga_click_trace" ga_cat="buy_page" ga_event="buy_page_click" ga_label="buy_page_next">下一頁 &gt;</a></li>
#                 <li class=""><a href="/region?pg=176" class="ga_click_trace" ga_cat="buy_page" ga_event="buy_page_click" ga_label="buy_page_last">最末頁</a></li>
#         </ul>
#     </div>
#
#     </div>
#     <div class="m-ad-banner">
#         <script language="javascript" type="text/javascript" src="//admd.yungching.com.tw/LAYOUT.aspx?ID=80.F033AB37C30201F73F142449D037028D"></script>
#     </div>
# </main>
# <app-im-container></app-im-container>
# <!--閒置頁面推薦-->
# <app-recommend-house-modal></app-recommend-house-modal>
#
#
# <div class="cirobox is-hide" tabindex="-1" role="dialog">
#     <div class="cirobox-hd">
#         <a style="top: 10px;" title="關閉" href="javascript:;" class="cirobox-icon-close"><i>&times;</i></a>
#     </div>
#     <div class="cirobox-bd"></div>
# </div>
#
#
# <script src="//cdn.yungching.com.tw/min/b=fp/yc/buy/Scripts&f=libs/jquery-1.11.1.min.js,libs/cirobox.js&v=202404290002" defer></script>
# <script>
#
#     window.addEventListener('DOMContentLoaded', function(){var openLightbox=function(t){t.preventDefault();var e=$(this),o=400,i=700;e.data("cheight")&&(o=e.data("cheight")),e.data("cwidth")&&(i=e.data("cwidth")),e.CiRoBox({click:!1,url:e.attr("href"),width:i,height:o,closeafter:function(){$(".cirobox-bd").html(""),$(".cirobox-bd").attr("style","")},openafter:function(){e.hasClass("m-btn-notice")&&($(".cirobox-bd").attr({style:"padding: 0.5em 1em"}),$(".cirobox-bd .bd-title").length<1&&$(".cirobox-bd").prepend('<div class="bd-wrap" style="border-bottom: 1px solid #e2e2e2;"><h3 class="bd-title">'+e.data("title")+"</h3></div>"));var t=0;$(window).on("message",function(e){e.originalEvent.origin.indexOf("yungching.com.tw")>-1&&("closeBox"===e.originalEvent.data?$.CiRoBox.close():isNaN(parseInt(e.originalEvent.data,10))||t===e.originalEvent.data||(t=parseInt(e.originalEvent.data,10),$(".cirobox, .cirobox iframe").height(t),$.CiRoBox.resize(700,t)))})}})};$(".openLightbox").on("click",openLightbox),function(){var t,e=$(".header-marquee-bd"),o=0,i=e.children("li").length;if(i>0){var n=function(){t=setInterval(function(){++o>=i&&(o=0),$("html").hasClass("no-csstransforms")?e.css({top:-26*o+"px"}):e.css({transform:"translate(0, "+-26*o+"px)"})},3450)};n(),e.on({mouseenter:function(){window.clearInterval(t)},mouseleave:function(){window.clearInterval(t),n()}})}}(),function(){var t=0===$("#hiddentopmbid").length||""!==$("#hiddentopmbid").val(),e=$(".l-header .m-header-bar .m-header-bar-bd .m-badge"),o=parseInt(e.text(),10)||0,i=document.location.host.indexOf("-t")>0?"memberyc-t":document.location.host.indexOf("-s")>0?"memberyc-s":"memberyc";t||0!==o||e.parent().removeClass("ga_click_trace").off("click").on("click",function(t){t.preventDefault();document.createElement("iframe");var e=[];return e.push('<div class="lb-ins">'),e.push('<div class="lb-title"><h3>收藏</h3></div>'),e.push('<div class="lb-content"><div class="l-unlogin" id="unlogin">'),e.push('<p>您尚未登入會員，請先<a target="_top" href="https://'+i+".yungching.com.tw/Account/Login?AFromURL="+window.location.href+'">登入</a>。</p>'),e.push('<p>若您還不是會員請先<a target="_top" href="https://'+i+'.yungching.com.tw/Account/SignUp?AccountPattern=Mobile&MBSourceID=108">加入會員</a>。</p>'),e.push("</div></div>"),$(this).CiRoBox({click:!1,keyboardclose:!1,backdropclose:!0,width:570,height:155,content:e.join("")}),!1})}();}, false);
# </script>
#
#
#     <link rel="stylesheet" href="/Angular/Styles/style.css?v=202404290002">
#     <script src="https://maps.googleapis.com/maps/api/js?key=&libraries=visualization"></script>
#     <script src="https://unpkg.com/@googlemaps/markerclustererplus/dist/index.min.js"></script>
#     <script src="//cdn.yungching.com.tw/fp/common/js/googlemap-infobox.js?v=202404290002"></script>
#     <script src="/Angular/Scripts/runtime.js?v=202404290002" type="module"></script>
#     <script src="/Angular/Scripts/polyfills.js?v=202404290002" type="module"></script>
#     <script src="/Angular/Scripts/main.js?v=202404290002" type="module"></script>
#
#
#     <footer class="l-footer">
#         <script type="text/javascript" src="//cdn.yungching.com.tw/min/b=fp/yc_common&f=footer.js&v=202404290002"></script>
#     </footer>
#
#         <script>
#     var timer;
# var _searchCondition = {
#                               "searchFor": '',
#                               "mainType": 'region',
#                               "addr": [
#                                 ['%e5%8f%b0%e5%8c%97%e5%b8%82'],
#                                 ['']
#                               ],
#                               "mrt":[],
#                               "isMap": false,
#                               "price": [],
#                               "pyeong": [],
#                               "keywords": [''],
#                               "filterBy": [''],
#                               "sortBy": [],
#                               "advConditions": {
#         "car": [],
#                                                 "houseType": [],
#                                                 "accessible": [],
#                                                 "houseAge": [],
#                                                 "directions": [],
#                                                 "floors": {
#             "sp": ["false"],
#                                                             "val": []
#     },
#                                                 "rooms": {
#             "sp": ["true"],
#                                                             "val": []
# },
#                                                 "sp":[]
#                                                 }
#
# };
#
#         </script>
#
#
#
#     <script src="//cdn.yungching.com.tw/min/b=fp/yc/buy/Scripts&f=libs/jquery.placeholder.min.js,libs/angular.min.js,ycapp.js,ycapp-searcCtrl.js,ycapp-searchCtrl.js,ycapp-factories.js,ycapp-directives.js,favorite.js&v=202404290002" defer></script>
#     <script type="text/javascript" src="//cdn.yungching.com.tw/fp/yc/common/elements/et-ng-belt.js?v=202404290002"></script>
#
# </body>
# </html>
